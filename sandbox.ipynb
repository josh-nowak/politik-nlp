# %%
from langchain_community.document_loaders import UnstructuredXMLLoader

# %%
loader = UnstructuredXMLLoader(
    "data/protocols/protocol_20-1.xml"
)
docs = loader.load()
docs[0].to_json()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
# ...
